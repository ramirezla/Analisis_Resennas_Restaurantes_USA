# %% [markdown]
# Importando Librerias

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import requests
from datetime import datetime, timedelta
import random
from scipy.stats import norm

import json
import os                       # Libreria para manejo de arhivos y directorios del sistema
import glob                     # crear listas de archivos a partir de búsquedas con comodines en un directorio
import pyarrow as pa
import jsonlines                # Permite procesar un registro por vez
import pyarrow.parquet as pq    # Permite leer archivos en formato parquet
import pickle5 as pickle        # Permite leer archivos con formatp pkl, para archivos version 5

# %% [markdown]
# Funcion que permite buscar archivos en un directorio segun un filtro deseado

# %%
# Recibe el directorio a trabajar y el patron o filtro que se desea mostrar.

def listar_archivos_segun_patron_con_directorio(directorio, patron):
    return glob.glob(directorio + patron)

# %% [markdown]
# - - -
# `Datasets: checkin - Cargando los archivos parquet reducidos como un Dataframe`

# %%
directorio = "../Datasets/Datasets_Yelp/checkin/"
ls_archivo = listar_archivos_segun_patron_con_directorio(directorio, "checkin-reducido_*.parquet")
df_list = []                                        # Un dataframe vacio para ir adicionando
for archivo in ls_archivo:                          # Leer cada archivo parquet en un DataFrame de Pandas y adicionarlo
    tabla_checkin = pq.read_table(source=archivo)   # Se crea una tabla con cada archivo
    df = tabla_checkin.to_pandas()                  # Se transforma la tabla en un dataframe
    df_list.append(df)                              # Se adicionan a los dataframe
df_checkin_reducido_concatenado = pd.concat(df_list)# Se concatenan todos los DataFrames en uno solo
df_checkin_reducido_concatenado = df_checkin_reducido_concatenado.reset_index(drop=True)  # Se resetea el indice a uno secuencial y consecutivo

# %%
df_checkin_reducido_concatenado.head().T
# Out:
#                                                              0  \
# business_id                             ---kPU91CF4Lq2-WlRu9Lw
# date         2020-03-13 21:10:56, 2020-06-02 22:18:06, 2020...
#
#                                                              1  \
# business_id                             --0iUa4sNDFiZFrAdIWhZQ
# date         2010-09-13 21:43:09, 2011-05-04 23:08:15, 2011...
#
#                                                     2  \
# business_id                    --30_8IhuyMHbSOcNWd6DQ
# date         2013-06-14 23:29:17, 2014-08-13 23:20:22
#
#                                                              3  \
# business_id                             --7PUidqRWpRSpXebiyxTg
# date         2011-02-15 17:12:00, 2011-07-28 02:46:10, 2012...
#
#                                                              4
# business_id                             --7jw19RH9JKXgFohspgQw
# date         2014-04-21 20:42:11, 2014-04-28 21:04:46, 2014...

# %% [markdown]
# - - -
# `Datasets: tip - Cargando los archivos parquet reducidos como un Dataframe`

# %%
directorio = "../Datasets/Datasets_Yelp/tip/"
ls_archivo = listar_archivos_segun_patron_con_directorio(directorio, "tip-reducido*.parquet")
df_list = []                                        # Un dataframe vacio para ir adicionando
for archivo in ls_archivo:                          # Leer cada archivo parquet en un DataFrame de Pandas y adicionarlo
    tabla_review = pq.read_table(source=archivo)    # Se crea una tabla con cada archivo
    df = tabla_review.to_pandas()                   # Se transforma la tabla en un dataframe
    df_list.append(df)                              # Se adicionan a los dataframe
df_tip_reducido_concatenado = pd.concat(df_list) # Se concatenan todos los DataFrames en uno solo
df_tip_reducido_concatenado = df_tip_reducido_concatenado.reset_index(drop=True)  # Se resetea el indice a uno secuencial y consecutivo

# %%
df_tip_reducido_concatenado.head().T
# Out:
#                                                        0  \
# user_id                           1viszljzsa8W7VnYPuWosw
# business_id                       Zg83olSjsdXAhE5EEy5IcQ
# text              Order crispy and they bake it up good.
# date                                          2018-04-01
# compliment_count                                       0
#
#                                                     1  \
# user_id                        YnlCpuaBa3qWBp4te8pGmA
# business_id                    XIKYdKWq72zUYsq8NBxcCQ
# text              The honey glazed salmon is amazing!
# date                                       2018-01-14
# compliment_count                                    0
#
#                                                                 2  \
# user_id                                    XJDLaoN1PerKw2woiKeepA
# business_id                                t0zwddmbOGQOADrAxEPHQQ
# text              Come by for some Jelly Bean sours this weekend!
# date                                                   2018-03-31
# compliment_count                                                0
#
#                                        3                       4
# user_id           9M_nk0kA3CTJt6UoxRAK_g  0LY6l9-Z2IrVtnfj6OX06w
# business_id       oJf3IZloLf_PDeEeZW5nDg  Zmwm6d872C8kWJr4b6UGfg
# text                   Meatball sandwich        Great tasty food
# date                          2018-03-27              2018-04-01
# compliment_count                       0                       0

# %% [markdown]
# - - -
# `Datasets: review - Cargando los archivos parquet reducidos como un Dataframe`

# %%
directorio = "../Datasets/Datasets_Yelp/review/"
ls_archivo = listar_archivos_segun_patron_con_directorio(directorio, "review-reducido_*.parquet")
df_list = []                                        # Un dataframe vacio para ir adicionando
for archivo in ls_archivo:                          # Leer cada archivo parquet en un DataFrame de Pandas y adicionarlo
    tabla_review = pq.read_table(source=archivo)    # Se crea una tabla con cada archivo
    df = tabla_review.to_pandas()                   # Se transforma la tabla en un dataframe
    df_list.append(df)                              # Se adicionan a los dataframe
df_review_reducido_concatenado = pd.concat(df_list) # Se concatenan todos los DataFrames en uno solo
df_review_reducido_concatenado = df_review_reducido_concatenado.reset_index(drop=True)  # Se resetea el indice a uno secuencial y consecutivo

# %%
df_review_reducido_concatenado.head().T
# Out:
#                                                              0  \
# review_id                               KU_O5udG6zpxOg-VcAEodg
# user_id                                 mh_-eMZ6K5RLWhZyISBhwA
# business_id                             XQfwVwDr-v0ZS3_CbbE5Xw
# stars                                                        3
# useful                                                       0
# funny                                                        0
# cool                                                         0
# text         If you decide to eat here, just be aware it is...
# date                                                2018-07-07
#
#                                                              1  \
# review_id                               lUUhg8ltDsUZ9h0xnwY4Dg
# user_id                                 RreNy--tOmXMl1en0wiBOg
# business_id                             cPepkJeRMtHapc_b2Oe_dw
# stars                                                        4
# useful                                                       1
# funny                                                        0
# cool                                                         1
# text         I was really between 3 and 4 stars for this on...
# date                                                2018-07-17
#
#                                                              2  \
# review_id                               JBWZmBy69VMggxj3eYn17Q
# user_id                                 aFa96pz67TwOFu4Weq5Agg
# business_id                             kq5Ghhh14r-eCxlVmlyd8w
# stars                                                        5
# useful                                                       0
# funny                                                        0
# cool                                                         0
# text         My boyfriend and I tried this deli for the fir...
# date                                                2018-08-23
#
#                                                              3  \
# review_id                               E9AB7V4z8xrt2uPF7T55FQ
# user_id                                 iYY5Ii1LGpZCpXFkHlMefw
# business_id                             Zx7n8mdt8OzLRXVzolXNhQ
# stars                                                        5
# useful                                                       0
# funny                                                        0
# cool                                                         0
# text         Amazing biscuits and (fill in the blank). Grea...
# date                                                2018-04-27
#
#                                                              4
# review_id                               A4n4YaE-owOVgTQcrVqHUw
# user_id                                 S7bjj-L07JuRr-tpX1UZLw
# business_id                             I6L0Zxi5Ww0zEWSAVgngeQ
# stars                                                        4
# useful                                                       0
# funny                                                        0
# cool                                                         0
# text         The cafe was extremely cute. We came at 8am an...
# date                                                2018-07-07

# %% [markdown]
# - - -
# `Datasets: user - Cargando los archivos parquet reducidos como un Dataframe`

# %%
directorio = "../Datasets/Datasets_Yelp/user/"
ls_archivo = listar_archivos_segun_patron_con_directorio(directorio, "user-reducido_*.parquet")
df_list = []                                    # Un dataframe vacio para ir adicionando
for archivo in ls_archivo:                      # Leer cada archivo parquet en un DataFrame de Pandas y adicionarlo
    tabla_user = pq.read_table(source=archivo)  # Se crea una tabla con cada archivo
    df = tabla_user.to_pandas()                 # Se transforma la tabla en un dataframe
    df_list.append(df)                          # Se adicionan a los dataframe
df_user_reducido_concatenado = pd.concat(df_list)                                   # Se concatenan todos los DataFrames en uno solo
df_user_reducido_concatenado = df_user_reducido_concatenado.reset_index(drop=True)  # Se resetea el indice a uno secuencial y consecutivo

# %%
df_user_reducido_concatenado.head().T
# Out:
#                                                                     0  \
# user_id                                        RDlBwvQe5oEQ8STtj6a5rg
# name                                                              Dee
# review_count                                                        4
# yelping_since                                              2018-11-06
# useful                                                              5
# funny                                                               0
# cool                                                                2
# elite
# friends             FrLfQoTXb7k68ZqBQTHSew, 88wN6ysc8Z1LSgaa-Au2MA...
# fans                                                                0
# average_stars                                                       4
# compliment_hot                                                      0
# compliment_more                                                     0
# compliment_profile                                                  0
# compliment_cute                                                     0
# compliment_list                                                     0
# compliment_note                                                     0
# compliment_plain                                                    0
# compliment_cool                                                     0
# compliment_funny                                                    0
# compliment_writer                                                   0
# compliment_photos                                                   0
#
#                                                                     1  \
# user_id                                        wZ5mQSbZR5UpGpnddGT7mw
# name                                                           Odalis
# review_count                                                      178
# yelping_since                                              2018-04-15
# useful                                                            542
# funny                                                              95
# cool                                                              429
# elite                                            2018,2019,20,20,2021
# friends             zGAGITTaxhi2J14604F_iA, WoMHyzfYFI8juti3DbaIvg...
# fans                                                               22
# average_stars                                                    4.16
# compliment_hot                                                      3
# compliment_more                                                     3
# compliment_profile                                                  0
# compliment_cute                                                     0
# compliment_list                                                     0
# compliment_note                                                    21
# compliment_plain                                                   29
# compliment_cool                                                    33
# compliment_funny                                                   33
# compliment_writer                                                  21
# compliment_photos                                                  26
#
#                                                                     2  \
# user_id                                        Oj8Ohm_2OlV6hjKMsQn69w
# name                                                            Emily
# review_count                                                        2
# yelping_since                                              2018-07-01
# useful                                                              1
# funny                                                               0
# cool                                                                0
# elite
# friends             YQhTRxurCw9uNe3stFyHHA, XUbfn0nkZgcsLixJJ_2WKQ...
# fans                                                                0
# average_stars                                                     1.5
# compliment_hot                                                      0
# compliment_more                                                     0
# compliment_profile                                                  0
# compliment_cute                                                     0
# compliment_list                                                     0
# compliment_note                                                     0
# compliment_plain                                                    0
# compliment_cool                                                     0
# compliment_funny                                                    0
# compliment_writer                                                   0
# compliment_photos                                                   0
#
#                                                                     3  \
# user_id                                        LRjvkbcZ5S4efH0xAVfkxw
# name                                                           Maggie
# review_count                                                        1
# yelping_since                                              2018-09-08
# useful                                                              2
# funny                                                               0
# cool                                                                0
# elite
# friends             VNHx2MZANbDBZml5eNMP2g, 5CmrzlkGIglc5A-4b4S8Ig...
# fans                                                                0
# average_stars                                                       5
# compliment_hot                                                      0
# compliment_more                                                     0
# compliment_profile                                                  0
# compliment_cute                                                     0
# compliment_list                                                     0
# compliment_note                                                     0
# compliment_plain                                                    0
# compliment_cool                                                     0
# compliment_funny                                                    0
# compliment_writer                                                   0
# compliment_photos                                                   0
#
#                                                                     4
# user_id                                        705syU_EmyN_hnlnmYy3nQ
# name                                                             Ella
# review_count                                                        2
# yelping_since                                              2018-03-13
# useful                                                              1
# funny                                                               0
# cool                                                                0
# elite
# friends             Ow2zUmCxcyOMd0ulTM30Zw, BkrImxMimcTtwNBC4NwZyQ...
# fans                                                                0
# average_stars                                                     3.5
# compliment_hot                                                      0
# compliment_more                                                     0
# compliment_profile                                                  0
# compliment_cute                                                     0
# compliment_list                                                     0
# compliment_note                                                     0
# compliment_plain                                                    0
# compliment_cool                                                     0
# compliment_funny                                                    0
# compliment_writer                                                   0
# compliment_photos                                                   0

# %% [markdown]
# - - -
# `Datasets: business - Cargando los archivos parquet reducidos como un Dataframe`

# %%
directorio = "../Datasets/Datasets_Yelp/business/"
ls_archivo = listar_archivos_segun_patron_con_directorio(directorio, "business*.parquet")
df_list = []                                    # Un dataframe vacio para ir adicionando
for archivo in ls_archivo:                      # Leer cada archivo parquet en un DataFrame de Pandas y adicionarlo
    tabla_user = pq.read_table(source=archivo)  # Se crea una tabla con cada archivo
    df = tabla_user.to_pandas()                 # Se transforma la tabla en un dataframe
    df_list.append(df)                          # Se adicionan a los dataframe
df_business_concatenado = pd.concat(df_list)    # Se concatenan todos los DataFrames en uno solo
df_business_concatenado = df_business_concatenado.reset_index(drop=True)    # Se resetea el indice a uno secuencial y consecutivo

# %%
df_business_concatenado.head().T
# Out:
#                                                               0  \
# business_id                              MTSW4McQd7CbVtyjqoe9mw
# name                                         St Honore Pastries
# address                                             935 Race St
# city                                               Philadelphia
# state                                                        CA
# postal_code                                               19107
# latitude                                                39.9555
# longitude                                              -75.1556
# stars                                                         4
# review_count                                                 80
# is_open                                                       1
# attributes    {'RestaurantsDelivery': 'False', 'OutdoorSeati...
# categories    Restaurants, Food, Bubble Tea, Coffee & Tea, B...
# hours         {'Monday': '7:0-20:0', 'Tuesday': '7:0-20:0', ...
#
#                                                               1  \
# business_id                              mWMc6_wTdE0EUBKIGXDVfA
# name                                   Perkiomen Valley Brewery
# address                                           101 Walnut St
# city                                                 Green Lane
# state                                                        MO
# postal_code                                               18054
# latitude                                                40.3382
# longitude                                              -75.4717
# stars                                                       4.5
# review_count                                                 13
# is_open                                                       1
# attributes    {'BusinessAcceptsCreditCards': 'True', 'Wheelc...
# categories                            Brewpubs, Breweries, Food
# hours         {'Wednesday': '14:0-22:0', 'Thursday': '16:0-2...
#
#                                                               2  \
# business_id                              CF33F8-E6oudUQ46HnavjQ
# name                                             Sonic Drive-In
# address                                           615 S Main St
# city                                               Ashland City
# state                                                        AZ
# postal_code                                               37015
# latitude                                                36.2696
# longitude                                              -87.0589
# stars                                                         2
# review_count                                                  6
# is_open                                                       1
# attributes    {'BusinessParking': 'None', 'BusinessAcceptsCr...
# categories    Burgers, Fast Food, Sandwiches, Food, Ice Crea...
# hours         {'Monday': '0:0-0:0', 'Tuesday': '6:0-22:0', '...
#
#                                                               3  \
# business_id                              n_0UpQx1hsNbnPUSlodU8w
# name                                            Famous Footwear
# address              8522 Eager Road, Dierbergs Brentwood Point
# city                                                  Brentwood
# state                                                        PA
# postal_code                                               63144
# latitude                                                38.6277
# longitude                                              -90.3405
# stars                                                       2.5
# review_count                                                 13
# is_open                                                       1
# attributes    {'BusinessAcceptsCreditCards': 'True', 'Restau...
# categories    Sporting Goods, Fashion, Shoe Stores, Shopping...
# hours         {'Monday': '0:0-0:0', 'Tuesday': '10:0-18:0', ...
#
#                                                               4
# business_id                              qkRM_2X51Yqxk3btlwAQIg
# name                                             Temple Beth-El
# address                                      400 Pasadena Ave S
# city                                             St. Petersburg
# state                                                        PA
# postal_code                                               33707
# latitude                                                27.7666
# longitude                                               -82.733
# stars                                                       3.5
# review_count                                                  5
# is_open                                                       1
# attributes                                                 None
# categories                  Synagogues, Religious Organizations
# hours         {'Monday': '9:0-17:0', 'Tuesday': '9:0-17:0', ...

# %% [markdown]
# - - -
# `Datasets: metadata-sitios - Cargando los archivos parquet reducidos como un Dataframe`

# %%
archivo = "../Datasets/Datasets_Google_Maps/metadata-sitios/metadata-sitios_reducido.parquet"
tabla_sitios = pq.read_table(source=archivo)                      # Se crea una tabla con cada archivo
df_sitios = tabla_sitios.to_pandas()                              # Se transforma la tabla en un dataframe

# %%
df_sitios.head().T
# Out:
#                                                                   0  \
# name                                                   Turkey Creek
# address                                     Turkey Creek, Tennessee
# gmap_id                       0x8864a58f0058d779:0x77f0f0f82ba4920e
# description                                                    None
# latitude                                                    35.9982
# longitude                                                  -87.3895
# category                                                    [River]
# avg_rating                                                      3.8
# num_of_reviews                                                    5
# price                                                          None
# hours                                                          None
# MISC                                                           None
# state                                                          None
# relative_results                                               None
# url               https://www.google.com/maps/place/Tennessee/da...
#
#                                                                   1  \
# name                               Shelter Insurance - Nathan Mizer
# address           Shelter Insurance - Nathan Mizer, 107A W Tenne...
# gmap_id                       0x885c336f4bd36d55:0x480c0e91ddfd240d
# description                                                    None
# latitude                                                    36.0263
# longitude                                                  -84.2434
# category          [Insurance agency, Auto insurance agency, Home...
# avg_rating                                                      4.3
# num_of_reviews                                                    3
# price                                                          None
# hours                                                          None
# MISC              {'Accessibility': ['Wheelchair accessible entr...
# state                                                          None
# relative_results  [0x885c336fe87d6049:0x12141fa4a69f85f5, 0x885c...
# url               https://www.google.com/maps/place//data=!4m2!3...
#
#                                                                   2  \
# name                                                     Flat Creek
# address                                 Flat Creek, Tennessee 37878
# gmap_id                       0x885ea23c1631d3df:0xeb621b8b97f25df6
# description                                                    None
# latitude                                                    35.6738
# longitude                                                  -83.8942
# category                                                    [River]
# avg_rating                                                        5
# num_of_reviews                                                    4
# price                                                          None
# hours                                                          None
# MISC                                                           None
# state                                                          None
# relative_results                                               None
# url               https://www.google.com/maps/place/Tennessee+37...
#
#                                                                   3  \
# name                                               Hurricane Branch
# address                           Hurricane Branch, Tennessee 37882
# gmap_id                       0x885ea154ea071f21:0x1a1ec761c433c2a7
# description                                                    None
# latitude                                                     35.677
# longitude                                                  -83.8577
# category                                                    [River]
# avg_rating                                                        5
# num_of_reviews                                                    1
# price                                                          None
# hours                                                          None
# MISC                                                           None
# state                                                          None
# relative_results                                               None
# url               https://www.google.com/maps/place/Tennessee+37...
#
#                                                                   4
# name                                               Autism Tennessee
# address           Autism Tennessee, 2607 Winford Ave, Nashville,...
# gmap_id                       0x886467cd4482dcff:0x636916ab972b869d
# description                                                    None
# latitude                                                    36.1149
# longitude                                                  -86.7533
# category                             [Social services organization]
# avg_rating                                                        5
# num_of_reviews                                                    4
# price                                                          None
# hours             [[Thursday, 10AM–3PM], [Friday, 10AM–3PM], [Sa...
# MISC              {'Accessibility': ['Wheelchair accessible entr...
# state                                           Closed ⋅ Opens 10AM
# relative_results  [0x8864657265da0d5f:0x8b83c74c7fb3b1a6, 0x8864...
# url               https://www.google.com/maps/place//data=!4m2!3...

# %% [markdown]
# - - -
# `Datasets: metadata-estados - Cargando los archivos parquet reducidos como un Dataframe`

# %%
directorio_origen = "../Datasets/Datasets_Google_Maps/reviews-estados/"    # Debido a la cantidad de directorios y archivos se permitira tener separados los archivos de origen.
directorios_reviews_estados = os.listdir(directorio_origen)                # Se obtiene un listado de todos los subdirectorios del directorio origen.
for sub_dir in directorios_reviews_estados:                                # Ciclo por cada subdirectorio
    nombre_archivo = sub_dir.replace("review-", '')
    archivos_reviews_estados = os.listdir(directorio_origen + sub_dir)     # Se guarda el directorio y el subdirectorio a utilizar
    directorio = directorio_origen + sub_dir + "/"
    ls_archivo = listar_archivos_segun_patron_con_directorio(directorio, "*.parquet")
    df_list = []                                                            # Un dataframe vacio para ir adicionando
    for archivo in ls_archivo:                                              # Leer cada archivo parquet en un DataFrame de Pandas y adicionarlo
        # print(directorio, nombre_archivo)
        # print(ls_archivo)
        tabla_estados = pq.read_table(source=archivo)                       # Se crea una tabla con cada archivo
        df = tabla_estados.to_pandas()                                      # Se transforma la tabla en un dataframe
        # df['estado'] = nombre_archivo
        df_list.append(df)                                                  # Se adicionan a los dataframe
    df_estados_concatenado = pd.concat(df_list)                             # Se concatenan todos los DataFrames en uno solo
    df['estado'] = nombre_archivo
df_estados_concatenado = df_estados_concatenado.reset_index(drop=True)      # Se resetea el indice a uno secuencial y consecutivo

# %%
df_estados_concatenado.head().T
# Out:
#                                                          0  \
# user_id                              101471856155148729010
# name                                       Julie A. Gerber
# time                                         1628003250740
# rating                                                   1
# text     Update: Their “reply” to my review amounted to...
# pics                                                  None
# resp     {'text': 'Thank you for the feedback. We would...
# gmap_id              0x8893863ea87bd5dd:0x9383ebf973e74abb
#
#                                                          1  \
# user_id                              115477234789038326051
# name                                      Martin Sheffield
# time                                         1595031217005
# rating                                                   5
# text     He's a knowledgeable doctor but the way he run...
# pics                                                  None
# resp     {'text': 'Thank you for reaching out. I’m forw...
# gmap_id              0x8893863ea87bd5dd:0x9383ebf973e74abb
#
#                                                          2  \
# user_id                              101805010244892834381
# name                                          Brian Truett
# time                                         1522924253567
# rating                                                   5
# text     Best doctor I've ever had, I never wait to be ...
# pics                                                  None
# resp                                                  None
# gmap_id              0x8893863ea87bd5dd:0x9383ebf973e74abb
#
#                                                          3  \
# user_id                              106344422881493743981
# name                                              Tina Sun
# time                                         1467907819586
# rating                                                   1
# text     I was told he is a good doctor. I was trying t...
# pics                                                  None
# resp                                                  None
# gmap_id              0x8893863ea87bd5dd:0x9383ebf973e74abb
#
#                                                          4
# user_id                              100875113069561776529
# name                                          James Haynes
# time                                         1480683415081
# rating                                                   5
# text     Takes the time to actually get to know his pat...
# pics                                                  None
# resp                                                  None
# gmap_id              0x8893863ea87bd5dd:0x9383ebf973e74abb
